# %% [markdown]
# <a href="https://colab.research.google.com/github/NYU-IEP-2022-2023-Assignments/QuickBite1/blob/main/QuickBite1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #Quick Bite 1, Due 1/29 11:59 PM
#
# The position of a damped pendulum bob is given by
#
# $x(t) = A e^{-t/(2 \tau)} \sin(\omega t)$
#
# 1. With $A = 100$ mm, $\tau = 5$ s, and $\omega$ = $\pi$, please plot $x(t)$ from 0 to 30 seconds. Label the axes and include the units.
#
# Hint, create variables `t = np.linspace(0,30,1000)` and `x = ...` (fill in the ... with the appropriate code) then `plt.plot(t,x)`
